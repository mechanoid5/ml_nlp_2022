# %% [markdown]
# **Статистическая языковая модель**
#
# Евгений Борисов <esborisov@sevsu.ru>
#
# подбираем наиболее вероятное продолжение цепочки слов

# %%
import re
import gzip
from random import sample
from itertools import chain
from pprint import pprint
from operator import mul
from functools import reduce 
from collections import Counter
from collections import OrderedDict
# from collections import defaultdict

#import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.util import ngrams

# %%
# !ls ../data

# %%
file_name = '../data/dostoevsky-besy-p2.txt.gz'

with gzip.open(file_name,'rt') as f:  text = f.read()[105:] # выкидываем заголовок
    
print('символов:%i\n'%(len(text)))
print(text[:364].strip())
# Out:
# символов:465490
#
# Теперь, когда уже все прошло, и я пишу хронику, мы уже знаем в чем дело; но тогда мы еще ничего не знали, и естественно, что нам представлялись странными разные вещи. По крайней мере мы со Степаном Трофимовичем в первое время заперлись и с испугом наблюдали издали. Я-то кой-куда еще выходил и по-прежнему приносил ему разные вести, без чего он и пробыть не мог.

# %%
text_ = [ 
    word_tokenize(
        re.sub(r'[^а-яa-z-]', ' ', s.lower()) # выкидываем лишние символы
        # s.lower()
    ) # разбиваем предложения на слова
    for s in sent_tokenize(text) # режем текст на отдельные предложения
]

print('предложений: %i\n'%(len(text_)))

sample(text_,2)
# Out:
# предложений: 5556
# [['-',
#   'уговаривал',
#   'николай',
#   'всеволодович',
#   'но',
#   'на',
#   'этот',
#   'раз',
#   'долго',
#   'не',
#   'мог',
#   'уговорить',
#   'она',
#   'молча',
#   'смотрела',
#   'на',
#   'него',
#   'все',
#   'с',
#   'тем',
#   'же',
#   'мучительным',
#   'недоумением',
#   'с',
#   'тяжелою',
#   'мыслию',
#   'в',
#   'своей',
#   'бедной',
#   'голове',
#   'и',
#   'все',
#   'так',
#   'же',
#   'усиливаясь',
#   'до',
#   'чего-то',
#   'додуматься'],
#  ['-', 'прошу', 'слова', '-', 'угрюмо', 'но', 'твердо', 'заявил', 'шигалев']]

# %% [markdown]
# ----

# %%
text_tokens = list(chain(*text_)) # собираем все токены (слова) из текста
vocab_size = len(set(text_tokens))

text_tokens_freq = Counter( text_tokens ) # оценка частоты использования слов

print('всего слов тексте: %i'%(len(text_tokens)))
print('размер словаря: %i'%(vocab_size))
text_tokens_freq.most_common()[:10] # наиболее частые токены
# Out:
# всего слов тексте: 74977
# размер словаря: 15670
# [('-', 3005),
#  ('и', 2983),
#  ('не', 1777),
#  ('в', 1750),
#  ('что', 1310),
#  ('я', 1267),
#  ('на', 891),
#  ('с', 862),
#  ('он', 822),
#  ('вы', 772)]

# %% [markdown]
# ----

# %%
# вынимаем все n-gram из текста
ngram_len = 2 # работаем с биграммами
text_ngrams = [ ngram for s in text_ for ngram in ngrams(s,ngram_len) ]
print('количество n-gram: %i'%(len(set(text_ngrams))))
sample(text_ngrams,5)
# Out:
# количество n-gram: 49001
# [('время', 'своими'),
#  ('личность', 'во'),
#  ('наконец', 'спросить'),
#  ('провидению', 'руками'),
#  ('не', 'сыскала')]

# %%
# cчитаем частоту n-gram
text_ngrams_freq = Counter(text_ngrams)
sample( text_ngrams_freq.items(), 7)
# Out:
# [(('называется', 'merci'), 1),
#  (('пьяны', 'церкви'), 1),
#  (('по', 'почте'), 4),
#  (('было', 'стать'), 1),
#  (('еще', 'при'), 2),
#  (('низводите', 'до'), 1),
#  (('все', 'но'), 1)]

# %%
text_ngrams_freq.most_common()[:10] # наиболее частые n-ngram
# Out:
# [(('-', 'я'), 201),
#  (('николай', 'всеволодович'), 166),
#  (('и', 'не'), 156),
#  (('петр', 'степанович'), 151),
#  (('я', 'не'), 111),
#  (('что', 'я'), 102),
#  (('потому', 'что'), 101),
#  (('что', 'вы'), 98),
#  (('-', 'вы'), 93),
#  (('как', 'бы'), 89)]

# %% [markdown]
# ----

# %% [markdown]
# Оценка вероятностей совместного использования слов со сглаживанием Лапласа
#
#
# $$
# P(w_n|w_{n-1}) = \frac{ C(w_{n-1} w_{n}) +1 }{ C(w_{n-1}) + V }
# $$

# %%
text_ngrams_prob = { # оценка совместного использования токенов
    ngram : (text_ngrams_freq[ngram]+1) / ( text_tokens_freq[ ngram[0] ] + vocab_size )
    for ngram in text_ngrams_freq 
}

text_ngrams_prob
# Out:
# {('теперь', 'когда'): 0.0003785488958990536,
#  ('когда', 'уже'): 0.0004431501645986326,
#  ('уже', 'все'): 0.0002523181732164259,
#  ('все', 'прошло'): 0.00012366289494837075,
#  ('прошло', 'и'): 0.00019141198239009763,
#  ('и', 'я'): 0.0018763737736557122,
#  ('я', 'пишу'): 0.00017712700005904233,
#  ('пишу', 'хронику'): 0.00012761613067891782,
#  ('хронику', 'мы'): 0.00012761613067891782,
#  ('мы', 'уже'): 0.00012657426745142712,
#  ('уже', 'знаем'): 0.00012615908660821296,
#  ('знаем', 'в'): 0.00012758356723653993,
#  ('в', 'чем'): 0.0010907003444316878,
#  ('чем', 'дело'): 0.00031721862707778203,
#  ('дело', 'но'): 0.0001905608842025027,
#  ('но', 'тогда'): 0.00012242899118511264,
#  ('тогда', 'мы'): 0.00012685525815045033,
#  ('мы', 'еще'): 0.0003164356686285678,
#  ('еще', 'ничего'): 0.00025081514923501377,
#  ('ничего', 'не'): 0.0036075949367088606,
#  ('не', 'знали'): 0.00034389866452685274,
#  ('знали', 'и'): 0.00012751849018107625,
#  ('и', 'естественно'): 0.00010722135849461212,
#  ('естественно', 'что'): 0.00012762427413694086,
#  ('что', 'нам'): 0.00011778563015312132,
#  ('нам', 'представлялись'): 0.00012742099898063202,
#  ('представлялись', 'странными'): 0.00012761613067891782,
#  ('странными', 'разные'): 0.00012760798826006508,
#  ('разные', 'вещи'): 0.00012754288629551687,
#  ('по', 'крайней'): 0.0022494376405898524,
#  ('крайней', 'мере'): 0.0022284477269833183,
#  ('мере', 'мы'): 0.0001272993444083763,
#  ('мы', 'со'): 0.0003164356686285678,
#  ('со', 'степаном'): 0.00038066235249333843,
#  ('степаном', 'трофимовичем'): 0.0005103017158895197,
#  ('трофимовичем', 'в'): 0.0001275754289723799,
#  ('в', 'первое'): 0.0001148105625717566,
#  ('первое', 'время'): 0.00012761613067891782,
#  ('время', 'заперлись'): 0.00012704865963664082,
#  ('заперлись', 'и'): 0.00012761613067891782,
#  ('и', 'с'): 0.0029485873586018335,
#  ('с', 'испугом'): 0.00012097749818533752,
#  ('испугом', 'наблюдали'): 0.00012759170653907497,
#  ('наблюдали', 'издали'): 0.00012762427413694086,
#  ('я-то', 'кой-куда'): 0.00012758356723653993,
#  ('кой-куда', 'еще'): 0.00012762427413694086,
#  ('еще', 'выходил'): 0.00012540757461750688,
#  ('выходил', 'и'): 0.00012760798826006508,
#  ('и', 'по-прежнему'): 0.0001608320377419182,
#  ('по-прежнему', 'приносил'): 0.00012755102040816328,
#  ('приносил', 'ему'): 0.00012762427413694086,
#  ('ему', 'разные'): 0.00018977732793522267,
#  ('разные', 'вести'): 0.00012754288629551687,
#  ('вести', 'без'): 0.00012759170653907497,
#  ('без', 'чего'): 0.00012678288431061807,
#  ('чего', 'он'): 0.0002542588354945334,
#  ('он', 'и'): 0.00109143827310211,
#  ('и', 'пробыть'): 0.00010722135849461212,
#  ('пробыть', 'не'): 0.00019142419601837673,
#  ('не', 'мог'): 0.0018341262108098814,
#  ('нечего', 'и'): 0.00025506950644050506,
#  ('и', 'говорить'): 0.00010722135849461212,
#  ('говорить', 'что'): 0.00019093686354378818,
#  ('что', 'по'): 0.0006478209658421672,
#  ('по', 'городу'): 0.0004998750312421895,
#  ('городу', 'пошли'): 0.00012756729174639623,
#  ('пошли', 'самые'): 0.0001275754289723799,
#  ('самые', 'разнообразные'): 0.00012753475322025253,
#  ('разнообразные', 'слухи'): 0.00012762427413694086,
#  ('слухи', 'то-есть'): 0.00012759170653907497,
#  ('то-есть', 'насчет'): 0.00012712133731646857,
#  ('насчет', 'пощечины'): 0.00012748597654258032,
#  ('пощечины', 'обморока'): 0.00012762427413694086,
#  ('обморока', 'лизаветы'): 0.00012761613067891782,
#  ('лизаветы', 'николаевны'): 0.0007015306122448979,
#  ('николаевны', 'и'): 0.00031887755102040814,
#  ('и', 'прочего'): 0.0001608320377419182,
#  ('прочего', 'случившегося'): 0.00012761613067891782,
#  ('случившегося', 'в'): 0.00012762427413694086,
#  ('в', 'то'): 0.0018369690011481056,
#  ('то', 'воскресенье'): 0.0001253054319904768,
#  ('но', 'удивительно'): 0.00012242899118511264,
#  ('удивительно', 'нам'): 0.00012759984688018373,
#  ('нам', 'было'): 0.00012742099898063202,
#  ('было', 'то'): 0.0002511616225040814,
#  ('то', 'через'): 0.0001253054319904768,
#  ('через', 'кого'): 0.00012746160219233955,
#  ('кого', 'это'): 0.00012750223128904755,
#  ('это', 'все'): 0.0009302325581395349,
#  ('все', 'могло'): 0.0001854943424225561,
#  ('могло', 'так'): 0.00012751849018107625,
#  ('так', 'скоро'): 0.0001867878712408941,
#  ('скоро', 'и'): 0.0001912655403251514,
#  ('и', 'точно'): 0.0002680533962365303,
#  ('точно', 'выйти'): 0.00012735608762098828,
#  ('выйти', 'наружу'): 0.0001275754289723799,
#  ('ни', 'одно'): 0.00012645422357106728,
#  ('одно', 'из'): 0.0003181673560292714,
#  ('из', 'присутствовавших'): 0.0001255020080321285,
#  ('присутствовавших', 'тогда'): 0.00012762427413694086,
#  ('тогда', 'лиц'): 0.00012685525815045033,
#  ('лиц', 'не'): 0.00012760798826006508,
#  ('не', 'имело'): 0.00017194933226342637,
#  ('имело', 'бы'): 0.00012761613067891782,
#  ('бы', 'кажется'): 0.00018719580681392738,
#  ('кажется', 'ни'): 0.00012714558169103624,
#  ('ни', 'нужды'): 0.00012645422357106728,
#  ('нужды', 'ни'): 0.00012759984688018373,
#  ('ни', 'выгоды'): 0.00012645422357106728,
#  ('выгоды', 'нарушить'): 0.00012759170653907497,
#  ('нарушить', 'секрет'): 0.00012761613067891782,
#  ('секрет', 'происшедшего'): 0.00012758356723653993,
#  ('прислуги', 'тогда'): 0.00012760798826006508,
#  ('тогда', 'не'): 0.0004439934035265762,
#  ('не', 'было'): 0.0020633919871611167,
#  ('было', 'один'): 0.0001255808112520407,
#  ('один', 'лебядкин'): 0.00012683112435791743,
#  ('лебядкин', 'мог'): 0.00012746160219233955,
#  ('мог', 'бы'): 0.0005720096606076013,
#  ('бы', 'что-нибудь'): 0.00012479720454261825,
#  ('что-нибудь', 'разболтать'): 0.00012742099898063202,
#  ('разболтать', 'не'): 0.00012762427413694086,
#  ('не', 'столько'): 0.00017194933226342637,
#  ('столько', 'по'): 0.00012751849018107625,
#  ('по', 'злобе'): 0.00012496875781054737,
#  ('злобе', 'потому'): 0.00012761613067891782,
#  ('потому', 'что'): 0.006449165402124431,
#  ('что', 'вышел'): 0.00017667844522968197,
#  ('вышел', 'тогда'): 0.00012740476493820868,
#  ('тогда', 'в'): 0.0005708486616770265,
#  ('в', 'крайнем'): 0.0001148105625717566,
#  ('крайнем', 'испуге'): 0.00012762427413694086,
#  ('испуге', 'а'): 0.00012759170653907497,
#  ('а', 'страх'): 0.00012272197336933178,
#  ('страх', 'к'): 0.00012759984688018373,
#  ('к', 'врагу'): 0.0001243781094527363,
#  ('врагу', 'уничтожает'): 0.00012761613067891782,
#  ('уничтожает', 'и'): 0.00012762427413694086,
#  ('и', 'злобу'): 0.00010722135849461212,
#  ('злобу', 'к'): 0.00012760798826006508,
#  ('к', 'нему'): 0.001990049751243781,
#  ('нему', 'а'): 0.0001273804216291956,
#  ('а', 'единственно'): 0.00018408296005399766,
#  ('единственно', 'по'): 0.0002548257628846276,
#  ('по', 'невоздержности'): 0.00012496875781054737,
#  ('но', 'лебядкин'): 0.00012242899118511264,
#  ('лебядкин', 'вместе'): 0.00012746160219233955,
#  ('вместе', 'с'): 0.0008283948257184732,
#  ('с', 'сестрицей'): 0.00012097749818533752,
#  ('сестрицей', 'на'): 0.00012762427413694086,
#  ('на', 'другой'): 0.0006038282712396595,
#  ('другой', 'же'): 0.0003180459258316901,
#  ('же', 'день'): 0.0004958472790380563,
#  ('день', 'пропал'): 0.00012725074759814214,
#  ('пропал', 'без'): 0.00012761613067891782,
#  ('без', 'вести'): 0.00012678288431061807,
#  ('вести', 'в'): 0.00012759170653907497,
#  ('в', 'доме'): 0.0008036739380022963,
#  ('доме', 'филиппова'): 0.00019119240328850933,
#  ('филиппова', 'его'): 0.00012759984688018373,
#  ('его', 'не'): 0.0007473376097652115,
#  ('не', 'оказалось'): 0.00011463288817561759,
#  ('оказалось', 'он'): 0.0001275754289723799,
#  ('он', 'переехал'): 0.00012127091923356779,
#  ('переехал', 'неизвестно'): 0.00012762427413694086,
#  ('неизвестно', 'куда'): 0.00012756729174639623,
#  ('куда', 'и'): 0.00012753475322025253,
#  ('точно', 'сгинул'): 0.00012735608762098828,
#  ('шатов', 'у'): 0.00012696800406297612,
#  ('у', 'которого'): 0.0003746721618583739,
#  ('которого', 'я'): 0.00019113149847094801,
#  ('я', 'хотел'): 0.0004723386668241129,
#  ('хотел', 'было'): 0.00031824836102094077,
#  ('было', 'справиться'): 0.0001255808112520407,
#  ('справиться', 'о'): 0.00012759170653907497,
#  ('о', 'марье'): 0.000125517760763148,
#  ('марье', 'тимофеевне'): 0.00031899961720045935,
#  ('тимофеевне', 'заперся'): 0.00012759984688018373,
#  ('заперся', 'и'): 0.00012760798826006508,
#  ('и', 'кажется'): 0.0005897174717203667,
#  ('кажется', 'все'): 0.00019071837253655435,
#  ('все', 'эти'): 0.0008038088171644099,
#  ('эти', 'восемь'): 0.0001271860095389507,
#  ('восемь', 'дней'): 0.0001913387333375853,
#  ('дней', 'просидел'): 0.00012742911755336096,
#  ('просидел', 'у'): 0.00012759170653907497,
#  ('у', 'себя'): 0.0004995628824778319,
#  ('себя', 'на'): 0.00018987341772151899,
#  ('на', 'квартире'): 0.00012076565424793189,
#  ('квартире', 'даже'): 0.00012760798826006508,
#  ('даже', 'прервав'): 0.00012592079581942958,
#  ('прервав', 'свои'): 0.00012761613067891782,
#  ('свои', 'занятия'): 0.00012739664946811899,
#  ('занятия', 'в'): 0.00012762427413694086,
#  ('в', 'городе'): 0.0009758897818599311,
#  ('меня', 'он'): 0.0002511773940345369,
#  ('он', 'не'): 0.0023647829250545717,
#  ('не', 'принял'): 0.00017194933226342637,
#  ('я', 'было'): 0.00017712700005904233,
#  ('было', 'зашел'): 0.0001255808112520407,
#  ('зашел', 'к'): 0.00012759984688018373,
#  ('нему', 'во'): 0.0001273804216291956,
#  ('во', 'вторник'): 0.0002540166380897949,
#  ('вторник', 'и'): 0.00012760798826006508,
#  ('и', 'стукнул'): 0.00010722135849461212,
#  ('стукнул', 'в'): 0.00012759170653907497,
#  ('в', 'дверь'): 0.0002870264064293915,
#  ('ответа', 'не'): 0.00019130212983037878,
#  ('не', 'получил'): 0.00017194933226342637,
#  ('получил', 'но'): 0.0001275754289723799,
#  ('но', 'уверенный'): 0.00012242899118511264,
#  ('уверенный', 'по'): 0.00012759984688018373,
#  ('по', 'несомненным'): 0.00012496875781054737,
#  ('несомненным', 'данным'): 0.00012761613067891782,
#  ('данным', 'что'): 0.00012762427413694086,
#  ('что', 'он'): 0.004004711425206125,
#  ('он', 'дома'): 0.00012127091923356779,
#  ('дома', 'постучался'): 0.00012743723716069835,
#  ('постучался', 'в'): 0.00012762427413694086,
#  ('в', 'другой'): 0.000574052812858783,
#  ('другой', 'раз'): 0.00044526429616436615,
#  ('тогда', 'он'): 0.00012685525815045033,
#  ('он', 'соскочив'): 0.00012127091923356779,
#  ('соскочив', 'по-видимому'): 0.00012761613067891782,
#  ('по-видимому', 'с'): 0.00012758356723653993,
#  ('с', 'постели'): 0.00030244374546334384,
#  ('постели', 'подошел'): 0.00012759170653907497,
#  ('подошел', 'крупными'): 0.00012755915555839021,
#  ('крупными', 'шагами'): 0.00012762427413694086,
#  ('шагами', 'к'): 0.00019141198239009763,
#  ('к', 'дверям'): 0.0006218905472636816,
#  ('дверям', 'и'): 0.0001913265306122449,
#  ('и', 'крикнул'): 0.00010722135849461212,
#  ('крикнул', 'мне'): 0.00012740476493820868,
#  ('мне', 'во'): 0.00012549413314927527,
#  ('во', 'весь'): 0.00038102495713469235,
#  ('весь', 'голос'): 0.00012725074759814214,
#  ('голос', 'шатова'): 0.00012744535780284203,
#  ('шатова', 'дома'): 0.0001274534794799898,
#  ('дома', 'нет'): 0.00012743723716069835,
#  ('я', 'с'): 0.0011808466670602822,
#  ('с', 'тем'): 0.0015727074764093879,
#  ('тем', 'и'): 0.0003171582619727244,
#  ('и', 'ушел'): 0.00010722135849461212,
#  ('трофимовичем', 'не'): 0.0001275754289723799,
#  ('не', 'без'): 0.00045853155270247036,
#  ('без', 'страха'): 0.00012678288431061807,
#  ('страха', 'за'): 0.00012759170653907497,
#  ('за', 'смелость'): 0.00012521129405872408,
#  ('смелость', 'предположения'): 0.00012760798826006508,
#  ('предположения', 'но'): 0.00012761613067891782,
#  ('но', 'обоюдно'): 0.00012242899118511264,
#  ('обоюдно', 'ободряя'): 0.00012762427413694086,
#  ('ободряя', 'друг'): 0.00012762427413694086,
#  ('друг', 'друга'): 0.00025484199796126404,
#  ('друга', 'остановились'): 0.00012752662118217177,
#  ('остановились', 'наконец'): 0.00012759984688018373,
#  ('наконец', 'на'): 0.00012693577050012695,
#  ('на', 'одной'): 0.00024153130849586377,
#  ('одной', 'мысли'): 0.0001274534794799898,
#  ('мысли', 'мы'): 0.00012751849018107625,
#  ('мы', 'решили'): 0.00012657426745142712,
#  ('решили', 'что'): 0.00012761613067891782,
#  ('что', 'виновником'): 0.00011778563015312132,
#  ('виновником', 'разошедшихся'): 0.00012762427413694086,
#  ('разошедшихся', 'слухов'): 0.00012762427413694086,
#  ('слухов', 'мог'): 0.00012760798826006508,
#  ('мог', 'быть'): 0.00025422651582560063,
#  ('быть', 'один'): 0.00012624668602449185,
#  ('один', 'только'): 0.0005073244974316697,
#  ('только', 'петр'): 0.00012554139727575167,
#  ('петр', 'степанович'): 0.009600808489135927,
#  ('степанович', 'хотя'): 0.00012641425952847481,
#  ('хотя', 'сам'): 0.00012707287629455492,
#  ('сам', 'он'): 0.00019029495718363463,
#  ('он', 'некоторое'): 0.00012127091923356779,
#  ('некоторое', 'время'): 0.00025513458349279245,
#  ('время', 'спустя'): 0.00012704865963664082,
#  ('спустя', 'в'): 0.00019135093761959434,
#  ('в', 'разговоре'): 0.0002296211251435132,
#  ('разговоре', 'с'): 0.00012759170653907497,
#  ('с', 'отцом'): 0.00012097749818533752,
#  ('отцом', 'уверял'): 0.00012760798826006508,
#  ('уверял', 'что'): 0.00019138755980861245,
#  ('что', 'застал'): 0.00011778563015312132,
#  ('застал', 'уже'): 0.00012758356723653993,
#  ('уже', 'историю'): 0.00012615908660821296,
#  ('историю', 'во'): 0.00012759170653907497,
#  ('во', 'всех'): 0.0006350415952244872,
#  ('всех', 'устах'): 0.00012685525815045033,
#  ('устах', 'преимущественно'): 0.00012762427413694086,
#  ('преимущественно', 'в'): 0.0001275754289723799,
#  ('в', 'клубе'): 0.0004592422502870264,
#  ('клубе', 'и'): 0.0002551508579447598,
#  ('и', 'совершенно'): 0.0003216640754838364,
#  ('совершенно', 'известною'): 0.0001272264631043257,
#  ('известною', 'до'): 0.00012762427413694086,
#  ('до', 'мельчайших'): 0.00018947767321417293,
#  ('мельчайших', 'подробностей'): 0.00019142419601837673,
#  ('подробностей', 'губернаторше'): 0.00012761613067891782,
#  ('губернаторше', 'и'): 0.00012760798826006508,
#  ('и', 'ее'): 0.00021444271698922425,
#  ('ее', 'супругу'): 0.00012637432073802604,
#  ('вот', 'что'): 0.0006960703663861292,
#  ('что', 'еще'): 0.00035335689045936394,
#  ('еще', 'замечательно'): 0.00012540757461750688,
#  ('замечательно', 'на'): 0.00012755915555839021,
#  ('на', 'второй'): 0.00012076565424793189,
#  ('второй', 'же'): 0.00012760798826006508,
#  ('день', 'в'): 0.00031812686899535534,
#  ('в', 'понедельник'): 0.0002296211251435132,
#  ('понедельник', 'ввечеру'): 0.00012760798826006508,
#  ('ввечеру', 'я'): 0.00012762427413694086,
#  ('я', 'встретил'): 0.00029521166676507054,
#  ('встретил', 'липутина'): 0.00012752662118217177,
#  ('липутина', 'и'): 0.00025519969376036747,
#  ('и', 'он'): 0.0013938776604299576,
#  ('он', 'уже'): 0.00048508367693427115,
#  ('уже', 'знал'): 0.00012615908660821296,
#  ('знал', 'все'): 0.0001274534794799898,
#  ('все', 'до'): 0.0002473257898967415,
#  ('до', 'последнего'): 0.00031579612202362154,
#  ('последнего', 'слова'): 0.00019136314345856987,
#  ('слова', 'стало'): 0.00012712133731646857,
#  ('стало', 'быть'): 0.00210030549898167,
#  ('быть', 'несомненно'): 0.00012624668602449185,
#  ('несомненно', 'узнал'): 0.00012755915555839021,
#  ('узнал', 'из'): 0.00012755102040816328,
#  ('из', 'первых'): 0.00018825301204819278,
#  ('многие', 'из'): 0.00038248231019315357,
#  ('из', 'дам'): 0.00018825301204819278,
#  ('дам', 'и'): 0.0002550369803621525,
#  ('и', 'из'): 0.0003752747547311424,
#  ('из', 'самых'): 0.0005647590361445783,
#  ('самых', 'светских'): 0.00012738853503184712,
#  ('светских', 'любопытствовали'): 0.00012762427413694086,
#  ('любопытствовали', 'и'): 0.00012761613067891782,
#  ('и', 'о'): 0.0007505495094622848,
#  ('о', 'загадочной'): 0.000125517760763148,
#  ('загадочной', 'хромоножке'): 0.00012762427413694086,
#  ('хромоножке', 'так'): 0.00012760798826006508,
#  ('так', 'называли'): 0.00012452524749392938,
#  ('называли', 'марью'): 0.00012760798826006508,
#  ('марью', 'тимофеевну'): 0.0005102691669855849,
#  ('нашлись', 'даже'): 0.00012762427413694086,
#  ('даже', 'пожелавшие'): 0.00012592079581942958,
#  ('пожелавшие', 'непременно'): 0.00012762427413694086,
#  ('непременно', 'увидать'): 0.00012733176290825746,
#  ('увидать', 'ее'): 0.00012761613067891782,
#  ('ее', 'лично'): 0.00012637432073802604,
#  ('лично', 'и'): 0.00012758356723653993,
#  ('и', 'познакомиться'): 0.00010722135849461212,
#  ('познакомиться', 'так'): 0.00012760798826006508,
#  ('так', 'что'): 0.002428242326131623,
#  ('что', 'господа'): 0.00011778563015312132,
#  ('господа', 'поспешившие'): 0.0001274778507234368,
#  ('поспешившие', 'припрятать'): 0.00012762427413694086,
#  ('припрятать', 'лебядкиных'): 0.00012762427413694086,
#  ('лебядкиных', 'очевидно'): 0.00012759170653907497,
#  ('очевидно', 'поступили'): 0.0001275103602167676,
#  ('поступили', 'и'): 0.00012762427413694086,
#  ('и', 'кстати'): 0.00010722135849461212,
#  ('но', 'на'): 0.0005509304603330069,
#  ('на', 'первом'): 0.00018114848137189784,
#  ('первом', 'плане'): 0.00019138755980861245,
#  ('плане', 'все-таки'): 0.00012761613067891782,
#  ('все-таки', 'стоял'): 0.00012723455690565557,
#  ('стоял', 'обморок'): 0.00012750223128904755,
#  ('обморок', 'лизаветы'): 0.00012761613067891782,
#  ('и', 'этим'): 0.00010722135849461212,
#  ('этим', 'интересовался'): 0.00012751849018107625,
#  ('интересовался', 'весь'): 0.00012762427413694086,
#  ('весь', 'свет'): 0.00012725074759814214,
#  ('свет', 'уже'): 0.00012758356723653993,
#  ('уже', 'по'): 0.0003153977165205324,
#  ('по', 'тому'): 0.00024993751562109475,
#  ('тому', 'одному'): 0.0002545986888167526,
#  ('одному', 'что'): 0.00025508577259103374,
#  ('что', 'дело'): 0.00017667844522968197,
#  ('дело', 'прямо'): 0.00012704058946833512,
#  ('прямо', 'касалось'): 0.00012728314134792846,
#  ('касалось', 'юлии'): 0.00012762427413694086,
#  ('юлии', 'михайловны'): 0.0018460754981220956,
#  ('михайловны', 'как'): 0.00012740476493820868,
#  ('как', 'родственницы'): 0.00012319822594554638,
#  ('родственницы', 'лизаветы'): 0.00012761613067891782,
#  ('ее', 'покровительницы'): 0.00012637432073802604,
#  ('и', 'чего-чего'): 0.00010722135849461212,
#  ('чего-чего', 'ни'): 0.00012762427413694086,
#  ('ни', 'болтали'): 0.00012645422357106728,
#  ('болтовне', 'способствовала'): 0.00012762427413694086,
#  ('способствовала', 'и'): 0.00012762427413694086,
#  ('и', 'таинственность'): 0.0001608320377419182,
#  ('таинственность', 'обстановки'): 0.00012761613067891782,
#  ('обстановки', 'оба'): 0.00012762427413694086,
#  ('оба', 'дома'): 0.00012744535780284203,
#  ('дома', 'были'): 0.00012743723716069835,
#  ('были', 'заперты'): 0.00012708095056551024,
#  ('заперты', 'наглухо'): 0.00012761613067891782,
#  ('наглухо', 'лизавета'): 0.00012761613067891782,
#  ('лизавета', 'николаевна'): 0.000574052812858783,
#  ('николаевна', 'как'): 0.00012756729174639623,
#  ('как', 'рассказывали'): 0.00012319822594554638,
#  ('рассказывали', 'лежала'): 0.00012761613067891782,
#  ('лежала', 'в'): 0.00012758356723653993,
#  ('в', 'белой'): 0.0002296211251435132,
#  ('белой', 'горячке'): 0.00025519969376036747,
#  ('горячке', 'то'): 0.00012759984688018373,
#  ('то', 'же'): 0.001754276047866675,
#  ('же', 'утверждали'): 0.00012396181975951408,
#  ('утверждали', 'и'): 0.00012759170653907497,
#  ('о', 'николае'): 0.000125517760763148,
#  ('николае', 'всеволодовиче'): 0.00012762427413694086,
#  ('всеволодовиче', 'с'): 0.00012762427413694086,
#  ('с', 'отвратительными'): 0.00012097749818533752,
#  ('отвратительными', 'подробностями'): 0.00012762427413694086,
#  ('подробностями', 'о'): 0.00012762427413694086,
#  ('о', 'выбитом'): 0.00018827664114472197,
#  ('выбитом', 'будто'): 0.00012761613067891782,
#  ('будто', 'бы'): 0.0008274457386544459,
#  ('бы', 'зубе'): 0.00012479720454261825,
#  ('зубе', 'и'): 0.00012761613067891782,
#  ('о', 'распухшей'): 0.000125517760763148,
#  ('распухшей', 'от'): 0.00012762427413694086,
#  ('от', 'флюса'): 0.0001259287243420224,
#  ('флюса', 'щеке'): 0.00012761613067891782,
#  ('щеке', 'его'): 0.00012760798826006508,
#  ('говорили', 'даже'): 0.00019104629688594535,
#  ('даже', 'по'): 0.00018888119372914436,
#  ('по', 'уголкам'): 0.00012496875781054737,
#  ('уголкам', 'что'): 0.00012762427413694086,
#  ('что', 'у'): 0.0011189634864546525,
#  ('у', 'нас'): 0.0026227051330086175,
#  ('нас', 'может'): 0.00012708095056551024,
#  ('может', 'быть'): 0.005059768515590412,
#  ('быть', 'будет'): 0.00012624668602449185,
#  ('будет', 'убийство'): 0.00012703252032520327,
#  ('убийство', 'что'): 0.00012761613067891782,
#  ('что', 'ставрогин'): 0.0004122497055359246,
#  ('ставрогин', 'не'): 0.0004433466337323453,
#  ('не', 'таков'): 0.00017194933226342637,
#  ('таков', 'чтобы'): 0.00012758356723653993,
#  ('чтобы', 'снести'): 0.00012658227848101267,
#  ('снести', 'такую'): 0.00012759170653907497,
#  ('такую', 'обиду'): 0.00012756729174639623,
#  ('обиду', 'и'): 0.00012759170653907497,
#  ('и', 'убьет'): 0.00010722135849461212,
#  ('убьет', 'шатова'): 0.00012762427413694086,
#  ('шатова', 'но'): 0.0001274534794799898,
#  ('но', 'таинственно'): 0.00012242899118511264,
#  ('таинственно', 'как'): 0.00012761613067891782,
#  ('как', 'в'): 0.0009239866945915979,
#  ('в', 'корсиканской'): 0.0001148105625717566,
#  ('корсиканской', 'вендетте'): 0.00012762427413694086,
#  ('мысль', 'эта'): 0.00012725884448969204,
#  ('эта', 'нравилась'): 0.00012739664946811899,
#  ('нравилась', 'но'): 0.00012762427413694086,
#  ('но', 'большинство'): 0.00012242899118511264,
#  ('большинство', 'нашей'): 0.00012759984688018373,
#  ('нашей', 'светской'): 0.00012749410339771785,
#  ('светской', 'молодежи'): 0.00012761613067891782,
#  ('молодежи', 'выслушивало'): 0.00012758356723653993,
#  ('выслушивало', 'все'): 0.00012762427413694086,
#  ('все', 'это'): 0.002473257898967415,
#  ('это', 'с'): 0.000310077519379845,
#  ('с', 'презрением'): 0.00018146624727800629,
#  ('презрением', 'и'): 0.00012760798826006508,
#  ('с', 'видом'): 0.0004839099927413501,
#  ('видом', 'самого'): 0.00012734797835084368,
#  ('самого', 'пренебрежительного'): 0.00012739664946811899,
#  ('пренебрежительного', 'равнодушия'): 0.00012762427413694086,
#  ('равнодушия', 'разумеется'): 0.00012762427413694086,
#  ('разумеется', 'напускного'): 0.00012723455690565557,
#  ('вообще', 'древняя'): 0.00012748597654258032,
#  ('древняя', 'враждебность'): 0.00012762427413694086,
#  ('враждебность', 'нашего'): 0.00012762427413694086,
#  ('нашего', 'общества'): 0.0001274778507234368,
#  ('общества', 'к'): 0.00012746160219233955,
#  ('к', 'николаю'): 0.0002487562189054726,
#  ('николаю', 'всеволодовичу'): 0.00044654248532788977,
#  ('всеволодовичу', 'обозначилась'): 0.00012758356723653993,
#  ('обозначилась', 'ярко'): 0.00012762427413694086,
#  ('даже', 'солидные'): 0.00012592079581942958,
#  ('солидные', 'люди'): 0.00012761613067891782,
#  ('люди', 'стремились'): 0.0001274534794799898,
#  ('стремились', 'обвинить'): 0.00012760798826006508,
#  ('обвинить', 'его'): 0.00012762427413694086,
#  ('его', 'хотя'): 0.0001245562682942019,
#  ('хотя', 'и'): 0.0012707287629455492,
#  ('и', 'сами'): 0.0003216640754838364,
#  ('сами', 'не'): 0.00031790437436419127,
#  ('знали', 'в'): 0.00012751849018107625,
#  ('шепотом', 'рассказывали'): 0.00012755915555839021,
#  ('рассказывали', 'что'): 0.00012761613067891782,
#  ('что', 'будто'): 0.0002944640753828033,
#  ('бы', 'он'): 0.00031199301135654563,
#  ('он', 'погубил'): 0.00012127091923356779,
#  ('погубил', 'честь'): 0.00012761613067891782,
#  ('честь', 'лизаветы'): 0.0001275103602167676,
#  ('и', 'что'): 0.0030021980378491394,
#  ('что', 'между'): 0.0002944640753828033,
#  ('между', 'ними'): 0.00019085183535848336,
#  ('ними', 'была'): 0.00012751849018107625,
#  ('была', 'интрига'): 0.00012701638511367967,
#  ('интрига', 'в'): 0.00012762427413694086,
#  ('в', 'швейцарии'): 0.0004592422502870264,
#  ('конечно', 'осторожные'): 0.00012707287629455492,
#  ('осторожные', 'люди'): 0.00012762427413694086,
#  ('люди', 'сдерживались'): 0.0001274534794799898,
#  ('сдерживались', 'но'): 0.00012762427413694086,
#  ('но', 'все'): 0.0004897159647404506,
#  ('все', 'однако'): 0.0002473257898967415,
#  ('однако', 'же'): 0.001778116466628564,
#  ('же', 'слушали'): 0.00012396181975951408,
#  ('слушали', 'с'): 0.00012761613067891782,
#  ('с', 'аппетитом'): 0.00012097749818533752,
#  ('были', 'и'): 0.0002541619011310205,
#  ('и', 'другие'): 0.00010722135849461212,
#  ('другие', 'разговоры'): 0.00012755102040816328,
#  ('разговоры', 'но'): 0.00019136314345856987,
#  ('но', 'не'): 0.0018364348677766896,
#  ('не', 'общие'): 0.00011463288817561759,
#  ('общие', 'а'): 0.00012762427413694086,
#  ('а', 'частные'): 0.00012272197336933178,
#  ('частные', 'редкие'): 0.00012761613067891782,
#  ('редкие', 'и'): 0.00012762427413694086,
#  ('и', 'почти'): 0.0006433281509676728,
#  ('почти', 'закрытые'): 0.00012691160606637477,
#  ('закрытые', 'чрезвычайно'): 0.00012762427413694086,
#  ('чрезвычайно', 'странные'): 0.0001273804216291956,
#  ('странные', 'и'): 0.00012760798826006508,
#  ('о', 'существовании'): 0.000125517760763148,
#  ('существовании', 'которых'): 0.00012762427413694086,
#  ('которых', 'я'): 0.00012752662118217177,
#  ('я', 'упоминаю'): 0.00011808466670602822,
#  ('упоминаю', 'лишь'): 0.00012760798826006508,
#  ('лишь', 'для'): 0.0003181066293421555,
#  ('для', 'предупреждения'): 0.00012657426745142712,
#  ('предупреждения', 'читателей'): 0.00012762427413694086,
#  ('читателей', 'единственно'): 0.00012762427413694086,
#  ('единственно', 'в'): 0.00019111932216347072,
#  ('в', 'виду'): 0.0005166475315729047,
#  ('виду', 'дальнейших'): 0.00012749410339771785,
#  ('дальнейших', 'событий'): 0.00012761613067891782,
#  ('событий', 'моего'): 0.00012759984688018373,
#  ('моего', 'рассказа'): 0.00019127773527161438,
#  ('именно', 'говорили'): 0.00012706480304955527,
#  ('говорили', 'иные'): 0.00012736419792396358,
#  ('иные', 'хмуря'): 0.00012755102040816328,
#  ('хмуря', 'брови'): 0.00012762427413694086,
#  ('брови', 'и'): 0.00012759984688018373,
#  ('и', 'бог'): 0.00010722135849461212,
#  ('бог', 'знает'): 0.0005097164702134438,
#  ('знает', 'на'): 0.00012733176290825746,
#  ('на', 'каком'): 0.00012076565424793189,
#  ('каком', 'основании'): 0.00012760798826006508,
#  ('основании', 'что'): 0.00019142419601837673,
#  ('что', 'николай'): 0.0004711425206124853,
#  ('николай', 'всеволодович'): 0.010543594923921965,
#  ('всеволодович', 'имеет'): 0.00012629451881788332,
#  ('имеет', 'какое-то'): 0.00012751849018107625,
#  ('какое-то', 'особенное'): 0.00012758356723653993,
#  ('особенное', 'дело'): 0.00012760798826006508,
#  ('дело', 'в'): 0.0005081623578733405,
#  ('в', 'нашей'): 0.0002870264064293915,
#  ('нашей', 'губернии'): 0.0005737234652897303,
#  ('губернии', 'что'): 0.00012746972594008922,
#  ('он', 'чрез'): 0.00012127091923356779,
#  ('чрез', 'графа'): 0.00012755102040816328,
#  ('графа', 'к'): 0.00044654248532788977,
#  ('к', 'вошел'): 0.0001243781094527363,
#  ('вошел', 'в'): 0.0002550044625780951,
#  ('в', 'петербурге'): 0.0014351320321469576,
#  ('петербурге', 'в'): 0.00038231171148209506,
#  ('в', 'какие-то'): 0.0001148105625717566,
#  ('какие-то', 'высшие'): 0.00012756729174639623,
#  ('высшие', 'отношения'): 0.00012760798826006508,
#  ('отношения', 'что'): 0.00012760798826006508,
#  ('он', 'даже'): 0.000545719136551055,
#  ('даже', 'может'): 0.0005666435811874331,
#  ('быть', 'служит'): 0.00012624668602449185,
#  ('служит', 'и'): 0.00012760798826006508,
#  ('и', 'чуть'): 0.0003216640754838364,
#  ('чуть', 'ли'): 0.000445746306673459,
#  ('ли', 'не'): 0.0005037466154524274,
#  ('не', 'снабжен'): 0.00011463288817561759,
#  ('снабжен', 'от'): 0.00012762427413694086,
#  ('от', 'кого-то'): 0.00018889308651303362,
#  ('кого-то', 'какими-то'): 0.00012760798826006508,
#  ('какими-то', 'поручениями'): 0.00012761613067891782,
#  ('когда', 'очень'): 0.00012661433274246644,
#  ('очень', 'уж'): 0.0001264942128897603,
#  ('уж', 'солидные'): 0.00012670256572695597,
#  ('солидные', 'и'): 0.00012761613067891782,
#  ('и', 'сдержанные'): 0.00010722135849461212,
#  ('сдержанные', 'люди'): 0.00012762427413694086,
#  ('люди', 'на'): 0.00019118021921998472,
#  ('на', 'этот'): 0.001147273715355353,
#  ('этот', 'слух'): 0.00019035532994923857,
#  ('слух', 'улыбались'): 0.00012758356723653993,
#  ('улыбались', 'благоразумно'): 0.00012761613067891782,
#  ('благоразумно', 'замечая'): 0.00012762427413694086,
#  ('замечая', 'что'): 0.00019138755980861245,
#  ('что', 'человек'): 0.00017667844522968197,
#  ('человек', 'живущий'): 0.00012679896024852597,
#  ('живущий', 'скандалами'): 0.00012762427413694086,
#  ('скандалами', 'и'): 0.00012762427413694086,
#  ('и', 'начинающий'): 0.00010722135849461212,
#  ('начинающий', 'у'): 0.00012762427413694086,
#  ('нас', 'с'): 0.00019062142584826535,
#  ('с', 'флюса'): 0.00012097749818533752,
#  ('флюса', 'не'): 0.00012761613067891782,
#  ('не', 'похож'): 0.00011463288817561759,
#  ('похож', 'на'): 0.00019141198239009763,
#  ('на', 'чиновника'): 0.00018114848137189784,
#  ('чиновника', 'то'): 0.00012759984688018373,
#  ('то', 'им'): 0.0002506108639809536,
#  ('им', 'шепотом'): 0.00012733176290825746,
#  ('шепотом', 'замечали'): 0.00012755915555839021,
#  ('замечали', 'что'): 0.00012762427413694086,
#  ('что', 'служит'): 0.00011778563015312132,
#  ('служит', 'он'): 0.00012760798826006508,
#  ('не', 'то'): 0.001662176878546455,
#  ('то', 'чтоб'): 0.0002506108639809536,
#  ('чтоб', 'оффициально'): 0.00012728314134792846,
#  ('оффициально', 'а'): 0.00012762427413694086,
#  ('а', 'так'): 0.0003681659201079953,
#  ('так', 'сказать'): 0.0004981009899757175,
#  ('сказать', 'конфиденциально'): 0.00012734797835084368,
#  ('конфиденциально', 'и'): 0.00012762427413694086,
#  ('что', 'в'): 0.0018256772673733805,
#  ('в', 'таком'): 0.0003444316877152698,
#  ('таком', 'случае'): 0.00025516713447307985,
#  ('случае', 'самою'): 0.00012746160219233955,
#  ('самою', 'службой'): 0.00012759170653907497,
#  ('службой', 'требуется'): 0.00012761613067891782,
#  ('требуется', 'чтобы'): 0.00012761613067891782,
#  ('чтобы', 'служащий'): 0.00012658227848101267,
#  ('служащий', 'как'): 0.00012760798826006508,
#  ('как', 'можно'): 0.0006775902427005051,
#  ('можно', 'менее'): 0.00012717792191275595,
#  ('менее', 'походил'): 0.00012759170653907497,
#  ('походил', 'на'): 0.00019142419601837673,
#  ('такое', 'замечание'): 0.00012748597654258032,
#  ('замечание', 'производило'): 0.00012761613067891782,
#  ('производило', 'эффект'): 0.00012762427413694086,
#  ('эффект', 'у'): 0.00012759984688018373,
#  ('нас', 'известно'): 0.00012708095056551024,
#  ('известно', 'было'): 0.00012746160219233955,
#  ('было', 'что'): 0.00037674243375612206,
#  ('что', 'на'): 0.0010600706713780918,
#  ('на', 'земство'): 0.00012076565424793189,
#  ('земство', 'нашей'): 0.00012762427413694086,
#  ('губернии', 'смотрят'): 0.00012746972594008922,
#  ('смотрят', 'в'): 0.00012761613067891782,
#  ('в', 'столице'): 0.0001148105625717566,
#  ('столице', 'с'): 0.00012762427413694086,
#  ('с', 'некоторым'): 0.00036293249455601257,
#  ('некоторым', 'особым'): 0.00012756729174639623,
#  ('особым', 'вниманием'): 0.00012762427413694086,
#  ('повторю', 'эти'): 0.00012761613067891782,
#  ('эти', 'слухи'): 0.00019077901430842608,
#  ('слухи', 'только'): 0.00012759170653907497,
#  ('только', 'мелькнули'): 0.00012554139727575167,
#  ('мелькнули', 'и'): 0.00012762427413694086,
#  ('и', 'исчезли'): 0.00010722135849461212,
#  ('исчезли', 'бесследно'): 0.00012762427413694086,
#  ('бесследно', 'до'): 0.00012762427413694086,
#  ('до', 'времени'): 0.0001263184488094486,
#  ('времени', 'при'): 0.0001274128814423138,
#  ('при', 'первом'): 0.00019070624880808594,
#  ('первом', 'появлении'): 0.00012759170653907497,
#  ('появлении', 'николая'): 0.00012762427413694086,
#  ('николая', 'всеволодовича'): 0.0017834394904458599,
#  ('всеволодовича', 'но'): 0.0001274128814423138,
#  ('но', 'замечу'): 0.00012242899118511264,
#  ('замечу', 'что'): 0.00038257986354651535,
#  ('что', 'причиной'): 0.00011778563015312132,
#  ('причиной', 'многих'): 0.00012761613067891782,
#  ('многих', 'слухов'): 0.00012759170653907497,
#  ('слухов', 'было'): 0.00012760798826006508,
#  ('было', 'отчасти'): 0.0001255808112520407,
#  ('отчасти', 'несколько'): 0.00012755102040816328,
#  ('несколько', 'кратких'): 0.00012711325791280032,
#  ('кратких', 'но'): 0.00012762427413694086,
#  ('но', 'злобных'): 0.00012242899118511264,
#  ('злобных', 'слов'): 0.00012762427413694086,
#  ('слов', 'неясно'): 0.0001274534794799898,
#  ('неясно', 'и'): 0.00012760798826006508,
#  ('и', 'отрывисто'): 0.0001608320377419182,
#  ('отрывисто', 'произнесенных'): 0.00012761613067891782,
#  ('произнесенных', 'в'): 0.00012762427413694086,
#  ('клубе', 'недавно'): 0.0001275754289723799,
#  ('недавно', 'возвратившимся'): 0.00012755915555839021,
#  ('возвратившимся', 'из'): 0.00012762427413694086,
#  ('из', 'петербурга'): 0.0008157630522088353,
#  ('петербурга', 'отставным'): 0.00012752662118217177,
#  ('отставным', 'капитаном'): 0.00012762427413694086,
#  ('капитаном', 'гвардии'): 0.00012761613067891782,
#  ('гвардии', 'артемием'): 0.00012761613067891782,
#  ('артемием', 'павловичем'): 0.00025521597652013015,
#  ('павловичем', 'гагановым'): 0.00019141198239009763,
#  ('гагановым', 'весьма'): 0.00012759984688018373,
#  ('весьма', 'крупным'): 0.00012742911755336096,
#  ('крупным', 'помещиком'): 0.00012762427413694086,
#  ('помещиком', 'нашей'): 0.00012761613067891782,
#  ('губернии', 'и'): 0.00019120458891013384,
#  ('и', 'уезда'): 0.00010722135849461212,
#  ('уезда', 'столичным'): 0.00012759984688018373,
#  ('столичным', 'светским'): 0.00012762427413694086,
#  ('светским', 'человеком'): 0.00012762427413694086,
#  ('человеком', 'и'): 0.00019128993177325768,
#  ('и', 'сыном'): 0.00010722135849461212,
#  ('сыном', 'покойного'): 0.00012759984688018373,
#  ('покойного', 'павла'): 0.00012762427413694086,
#  ('павла', 'павловича'): 0.00012762427413694086,
#  ('павловича', 'гаганова'): 0.00019141198239009763,
#  ('гаганова', 'того'): 0.00012756729174639623,
#  ('того', 'самого'): 0.00019005384859043396,
#  ('самого', 'почтенного'): 0.00012739664946811899,
#  ('почтенного', 'старшины'): 0.00012761613067891782,
#  ('старшины', 'с'): 0.00012762427413694086,
#  ('с', 'которым'): 0.00024195499637067505,
#  ('которым', 'николай'): 0.00012749410339771785,
#  ('всеволодович', 'имел'): 0.00012629451881788332,
#  ('имел', 'четыре'): 0.00012746972594008922,
#  ('четыре', 'слишком'): 0.00012744535780284203,
#  ('слишком', 'года'): 0.00012705673083031574,
#  ('года', 'тому'): 0.0002548744743213967,
#  ('тому', 'назад'): 0.0003818980332251289,
#  ('назад', 'то'): 0.00012736419792396358,
#  ('то', 'необычайное'): 0.00018795814798571519,
#  ('необычайное', 'по'): 0.00019142419601837673,
#  ('по', 'своей'): 0.00012496875781054737,
#  ('своей', 'грубости'): 0.00012735608762098828,
#  ('грубости', 'и'): 0.00012761613067891782,
#  ('и', 'внезапности'): 0.00010722135849461212,
#  ('внезапности', 'столкновение'): 0.00012762427413694086,
#  ('столкновение', 'о'): 0.00012762427413694086,
#  ('о', 'котором'): 0.0005648299234341659,
#  ('котором', 'я'): 0.00025489071560568405,
#  ('я', 'уже'): 0.0005904233335301411,
#  ('уже', 'упоминал'): 0.00018923862991231943,
#  ('упоминал', 'прежде'): 0.00012760798826006508,
#  ('прежде', 'в'): 0.00019102196752626553,
#  ('в', 'начале'): 0.0001148105625717566,
#  ('начале', 'моего'): 0.00012760798826006508,
#  ('всем', 'тотчас'): 0.00012726694241170855,
#  ('тотчас', 'же'): 0.004951437821367358,
#  ('же', 'стало'): 0.0001859427296392711,
#  ('стало', 'известно'): 0.00019093686354378818,
#  ('известно', 'что'): 0.00038238480657701865,
#  ('что', 'юлия'): 0.00023557126030624264,
#  ('юлия', 'михайловна'): 0.003814124976161719,
#  ('михайловна', 'сделала'): 0.0001271536652043995,
#  ('сделала', 'варваре'): 0.00012758356723653993,
#  ('варваре', 'петровне'): 0.0010200828817341408,
#  ('петровне', 'чрезвычайный'): 0.00012749410339771785,
#  ('чрезвычайный', 'визит'): 0.00012762427413694086,
#  ('визит', 'и'): 0.00012759984688018373,
#  ('у', 'крыльца'): 0.00024978144123891593,
#  ('крыльца', 'дома'): 0.0001275754289723799,
#  ('дома', 'ей'): 0.00012743723716069835,
#  ('ей', 'объявили'): 0.00012709710218607016,
#  ('объявили', 'что'): 0.00012760798826006508,
#  ('по', 'нездоровью'): 0.00018745313671582103,
#  ('нездоровью', 'не'): 0.00012761613067891782,
#  ('не', 'могут'): 0.000286582220439044,
#  ('могут', 'принять'): 0.00012755102040816328,
#  ('также', 'и'): 0.00012761613067891782,
#  ('и', 'то'): 0.000804160188709591,
#  ('то', 'что'): 0.0022554977758285823,
#  ('что', 'дня'): 0.00011778563015312132,
#  ('дня', 'через'): 0.00019104629688594535,
#  ('через', 'два'): 0.00012746160219233955,
#  ('два', 'после'): 0.00012714558169103624,
#  ('после', 'своего'): 0.00019066988686920045,
#  ('своего', 'визита'): 0.00012729124236252545,
#  ('визита', 'юлия'): 0.00012762427413694086,
#  ('михайловна', 'посылала'): 0.0001271536652043995,
#  ('посылала', 'узнать'): 0.00012762427413694086,
#  ('узнать', 'о'): 0.00012752662118217177,
#  ('о', 'здоровье'): 0.000125517760763148,
#  ('здоровье', 'варвары'): 0.00012759170653907497,
#  ('варвары', 'петровны'): 0.00044654248532788977,
#  ('петровны', 'нарочного'): 0.00012758356723653993,
#  ('наконец', 'принялась'): 0.00012693577050012695,
#  ('принялась', 'везде'): 0.00012762427413694086,
#  ('везде', 'защищать'): 0.00012756729174639623,
#  ('защищать', 'варвару'): 0.00012762427413694086,
#  ('варвару', 'петровну'): 0.00019142419601837673,
#  ('петровну', 'конечно'): 0.00012761613067891782,
#  ('конечно', 'лишь'): 0.00012707287629455492,
#  ('лишь', 'в'): 0.00019086397760529329,
#  ('в', 'самом'): 0.0017795637198622274,
#  ('самом', 'высшем'): 0.0001273074474856779,
#  ('высшем', 'смысле'): 0.00025516713447307985,
#  ('смысле', 'то'): 0.0001275103602167676,
#  ('то', 'есть'): 0.0001253054319904768,
#  ('есть', 'по'): 0.00012701638511367967,
#  ('по', 'возможности'): 0.0003124218945263684,
#  ('возможности', 'в'): 0.00019138755980861245,
#  ('самом', 'неопределенном'): 0.0001273074474856779,
#  ('все', 'же'): 0.0001854943424225561,
#  ('же', 'первоначальные'): 0.00012396181975951408,
#  ('первоначальные', 'торопливые'): 0.00012761613067891782,
#  ('торопливые', 'намеки'): 0.00012762427413694086,
#  ('намеки', 'о'): 0.00012761613067891782,
#  ('о', 'воскресной'): 0.000125517760763148,
#  ('воскресной', 'истории'): 0.00012762427413694086,
#  ('истории', 'выслушала'): 0.00012755102040816328,
#  ('выслушала', 'строго'): 0.00012762427413694086,
#  ('строго', 'и'): 0.0001275754289723799,
#  ('и', 'холодно'): 0.0001608320377419182,
#  ('холодно', 'так'): 0.00012759170653907497,
#  ('в', 'последующие'): 0.0001148105625717566,
#  ('последующие', 'дни'): 0.00012762427413694086,
#  ('дни', 'в'): 0.00012753475322025253,
#  ('в', 'ее'): 0.0005166475315729047,
#  ('ее', 'присутствии'): 0.00012637432073802604,
#  ('присутствии', 'они'): 0.00012759984688018373,
#  ('они', 'уже'): 0.00012672665061462426,
#  ('уже', 'не'): 0.0008831136062574906,
#  ('не', 'возобновлялись'): 0.00011463288817561759,
#  ('таким', 'образом'): 0.0012096517476284459,
#  ('образом', 'и'): 0.00025471217524197657,
#  ('и', 'укрепилась'): 0.00010722135849461212,
#  ('укрепилась', 'везде'): 0.00012762427413694086,
#  ('везде', 'мысль'): 0.00012756729174639623,
#  ('мысль', 'что'): 0.0005726648002036142,
#  ('что', 'юлии'): 0.00011778563015312132,
#  ('юлии', 'михайловне'): 0.0007638933095677638,
#  ('михайловне', 'известна'): 0.00012753475322025253,
#  ('известна', 'не'): 0.00012759984688018373,
#  ('не', 'только'): 0.000573164440878088,
#  ('только', 'вся'): 0.00012554139727575167,
#  ('вся', 'эта'): 0.00025489071560568405,
#  ('эта', 'таинственная'): 0.00012739664946811899,
#  ('таинственная', 'история'): 0.00012760798826006508,
#  ('история', 'но'): 0.00012756729174639623,
#  ('но', 'и'): 0.0006121449559255632,
#  ('и', 'весь'): 0.0001608320377419182,
#  ('весь', 'ее'): 0.00012725074759814214,
#  ('ее', 'таинственный'): 0.00012637432073802604,
#  ('таинственный', 'смысл'): 0.00012761613067891782,
#  ('смысл', 'до'): 0.00012761613067891782,
#  ('подробностей', 'и'): 0.00012761613067891782,
#  ('и', 'не'): 0.008416876641827052,
#  ('не', 'как'): 0.00022926577635123518,
#  ('как', 'посторонней'): 0.00012319822594554638,
#  ('посторонней', 'а'): 0.00012762427413694086,
#  ('а', 'как'): 0.0003681659201079953,
#  ('как', 'соучастнице'): 0.00012319822594554638,
#  ('замечу', 'кстати'): 0.00012752662118217177,
#  ('кстати', 'что'): 0.00025477707006369424,
#  ('что', 'она'): 0.0013545347467608952,
#  ('она', 'начала'): 0.00012576243476073698,
#  ('начала', 'уже'): 0.0001274778507234368,
#  ('уже', 'приобретать'): 0.00012615908660821296,
#  ('приобретать', 'у'): 0.00012762427413694086,
#  ('нас', 'помаленьку'): 0.00012708095056551024,
#  ('помаленьку', 'то'): 0.00012762427413694086,
#  ('то', 'высшее'): 0.0001253054319904768,
#  ('высшее', 'влияние'): 0.00012760798826006508,
#  ('влияние', 'которого'): 0.00012756729174639623,
#  ('которого', 'так'): 0.00012742099898063202,
#  ('так', 'несомненно'): 0.00012452524749392938,
#  ('несомненно', 'добивалась'): 0.00012755915555839021,
#  ('добивалась', 'и'): 0.00012762427413694086,
#  ('и', 'жаждала'): 0.00010722135849461212,
#  ('жаждала', 'и'): 0.00012759984688018373,
#  ('и', 'уже'): 0.0009113815472042031,
#  ('уже', 'начинала'): 0.00012615908660821296,
#  ('начинала', 'видеть'): 0.00012762427413694086,
#  ('видеть', 'себя'): 0.00012759170653907497,
#  ('себя', 'окруженною'): 0.00012658227848101267,
#  ('часть', 'общества'): 0.00012760798826006508,
#  ('общества', 'признала'): 0.00012746160219233955,
#  ('признала', 'за'): 0.00012762427413694086,
#  ('за', 'нею'): 0.00031302823514681025,
#  ('нею', 'практический'): 0.00012748597654258032,
#  ('практический', 'ум'): 0.00012762427413694086,
#  ('ум', 'и'): 0.00031873525849429466,
#  ('и', 'такт'): 0.00010722135849461212,
#  ('такт', 'но'): 0.00012761613067891782,
#  ('но', 'об'): 0.0002448579823702253,
#  ('об', 'этом'): 0.0012084207848374992,
#  ('этом', 'после'): 0.00019073049780659929,
#  ('ее', 'же'): 0.00012637432073802604,
#  ('же', 'покровительством'): 0.00012396181975951408,
#  ('покровительством', 'объяснялись'): 0.00012762427413694086,
#  ('объяснялись', 'отчасти'): 0.00012762427413694086,
#  ('отчасти', 'и'): 0.00012755102040816328,
#  ('и', 'весьма'): 0.0002680533962365303,
#  ('весьма', 'быстрые'): 0.00012742911755336096,
#  ('быстрые', 'успехи'): 0.00012762427413694086,
#  ('успехи', 'петра'): 0.00012760798826006508,
#  ('петра', 'степановича'): 0.0019743965352525318,
#  ('степановича', 'в'): 0.00025477707006369424,
#  ('в', 'нашем'): 0.0005166475315729047,
#  ('нашем', 'обществе'): 0.00025508577259103374,
#  ('обществе', '-'): 0.00012754288629551687,
#  ('-', 'успехи'): 0.000107095046854083,
#  ('успехи', 'особенно'): 0.00012760798826006508,
#  ('особенно', 'поразившие'): 0.00012728314134792846,
#  ('поразившие', 'тогда'): 0.00012762427413694086,
#  ('тогда', 'степана'): 0.00012685525815045033,
#  ('степана', 'трофимовича'): 0.0018472514172877253,
#  ('мы', 'с'): 0.0006328713372571356,
#  ('с', 'ним'): 0.0014517299782240503,
#  ('ним', 'может'): 0.00012708902586261675,
#  ('быть', 'и'): 0.0012624668602449186,
#  ('и', 'преувеличивали'): 0.00010722135849461212,
#  ('во-первых', 'петр'): 0.00012753475322025253,
#  ('степанович', 'перезнакомился'): 0.00012641425952847481,
#  ('перезнакомился', 'почти'): 0.00012762427413694086,
#  ('почти', 'мгновенно'): 0.00012691160606637477,
#  ('мгновенно', 'со'): 0.00012759170653907497,
#  ('со', 'всем'): 0.00038066235249333843,
#  ('всем', 'городом'): 0.00012726694241170855,
#  ('городом', 'в'): 0.00012762427413694086,
#  ('в', 'первые'): 0.0002296211251435132,
#  ('первые', 'же'): 0.00012754288629551687,
#  ('же', 'четыре'): 0.00012396181975951408,
#  ('четыре', 'дня'): 0.00012744535780284203,
#  ('дня', 'после'): 0.00025472839584792715,
#  ('своего', 'появления'): 0.00012729124236252545,
#  ('появился', 'он'): 0.00012759984688018373,
#  ('он', 'в'): 0.00109143827310211,
#  ('в', 'воскресенье'): 0.000574052812858783,
#  ('воскресенье', 'а'): 0.00012754288629551687,
#  ('а', 'во'): 0.00024544394673866357,
#  ('вторник', 'я'): 0.00012760798826006508,
#  ('уже', 'встретил'): 0.00012615908660821296,
#  ('встретил', 'его'): 0.00012752662118217177,
#  ('его', 'в'): 0.001183284548794918,
#  ('в', 'коляске'): 0.0001722158438576349,
#  ('коляске', 'с'): 0.00019136314345856987,
#  ('с', 'артемием'): 0.00018146624727800629,
#  ('гагановым', 'человеком'): 0.00012759984688018373,
#  ('человеком', 'гордым'): 0.00012752662118217177,
#  ('гордым', 'раздражительным'): 0.00012761613067891782,
#  ('раздражительным', 'и'): 0.00012762427413694086,
#  ('и', 'заносчивым'): 0.00010722135849461212,
#  ('заносчивым', 'несмотря'): 0.00012762427413694086,
#  ('несмотря', 'на'): 0.001910828025477707,
#  ('на', 'всю'): 0.0006038282712396595,
#  ('всю', 'его'): 0.00019068200597470284,
#  ('его', 'светскость'): 0.0001245562682942019,
#  ('светскость', 'и'): 0.00012762427413694086,
#  ('которым', 'по'): 0.00012749410339771785,
#  ('по', 'характеру'): 0.00012496875781054737,
#  ('характеру', 'его'): 0.00012761613067891782,
#  ('его', 'довольно'): 0.00018683440244130286,
#  ('довольно', 'трудно'): 0.0001271860095389507,
#  ('трудно', 'было'): 0.000318775900541919,
#  ('было', 'ужиться'): 0.0001255808112520407,
#  ('у', 'губернатора'): 0.00012489072061945796,
#  ('губернатора', 'петр'): 0.00012761613067891782,
#  ('степанович', 'был'): 0.00018962138929271222,
#  ('был', 'тоже'): 0.00012603982858583313,
#  ('тоже', 'принят'): 0.000126806999746386,
#  ('принят', 'прекрасно'): 0.00012762427413694086,
#  ('прекрасно', 'до'): 0.00012755915555839021,
#  ('до', 'того'): 0.0010737068148803132,
#  ('того', 'что'): 0.0013303769401330377,
#  ('что', 'тотчас'): 0.00011778563015312132,
#  ('же', 'стал'): 0.00012396181975951408,
#  ('стал', 'в'): 0.00012735608762098828,
#  ('в', 'положение'): 0.0001148105625717566,
#  ('положение', 'близкого'): 0.00012759984688018373,
#  ('близкого', 'или'): 0.00012762427413694086,
#  ('или', 'так-сказать'): 0.00018975332068311195,
#  ('так-сказать', 'обласканного'): 0.00012758356723653993,
#  ('обласканного', 'молодого'): 0.00012762427413694086,
#  ('молодого', 'человека'): 0.0003826774666751706,
#  ('человека', 'обедал'): 0.0001272993444083763,
#  ('обедал', 'у'): 0.00012761613067891782,
#  ('у', 'юлии'): 0.0004995628824778319,
#  ('михайловны', 'почти'): 0.00012740476493820868,
#  ('почти', 'ежедневно'): 0.00019036740909956216,
#  ('познакомился', 'он'): 0.00012760798826006508,
#  ('он', 'с'): 0.0013339801115692456,
#  ('с', 'нею'): 0.0006653762400193564,
#  ('нею', 'еще'): 0.00012748597654258032,
#  ('еще', 'в'): 0.0009405568096313017,
#  ('швейцарии', 'но'): 0.00012756729174639623,
#  ('но', 'в'): 0.0017140058765915769,
#  ('в', 'быстром'): 0.0001148105625717566,
#  ('быстром', 'успехе'): 0.00012761613067891782,
#  ('успехе', 'его'): 0.00012760798826006508,
#  ('доме', 'его'): 0.00012746160219233955,
#  ('его', 'превосходительства'): 0.0001245562682942019,
#  ('превосходительства', 'действительно'): 0.00012760798826006508,
#  ('действительно', 'заключалось'): 0.0001272993444083763,
#  ('заключалось', 'нечто'): 0.00019142419601837673,
#  ('нечто', 'любопытное'): 0.00012752662118217177,
#  ('все-таки', 'он'): 0.00019085183535848336,
#  ('он', 'слыл'): 0.00012127091923356779,
#  ('слыл', 'же'): 0.00012762427413694086,
#  ...}

# %% [markdown]
# ---

# %% [markdown]
# по предыдущим словам подобираем слово с наибольшей вероятностью
#
# $$
# P(w_1,\ldots, w_n) = \prod_{k=1}^{n} P(w_k|w_k-1)
# $$

# %%
def get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    if ngram in text_ngrams_prob: return text_ngrams_prob[ngram]
    token_0_freq = text_tokens_freq[ngram[0]] if ngram[0] in text_tokens_freq else 0.
    return 1./(token_0_freq+len(text_tokens_freq))

# %%
def get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    if ngram in text_ngrams_prob: return text_ngrams_prob[ngram]
    token_0_freq = text_tokens_freq[ngram[0]] if ngram[0] in text_tokens_freq else 0.
    return 1./(token_0_freq+len(text_tokens_freq))

# %%
# оценка предложения
def get_sentence_prob(sentence,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    return reduce( mul, [ 
        get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in ngrams(sentence,ngram_len) 
    ] )

# get_sentence_prob(sentence)

# %%
# оценка всех возможных продолжений предложения
def get_next_token_prob(sentence,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    
    sentence_prob = get_sentence_prob( # оценка предложения
            sentence,
            text_ngrams_prob=text_ngrams_prob,
            text_tokens_freq=text_tokens_freq
        )
    
    token_next = { # оценки всех возможных продолжений
        ngram[1] : 
            sentence_prob*
              get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in text_ngrams_prob if ngram[0]==sentence[-1] 
    }
    
    return token_next

# get_next_token_prob(sentence)

# %%
# from collections import defaultdict

# %%
def get_top_prob_token(tokens_prob,n=3):  # n наиболее вероятных продолжений
    kf = lambda k: tokens_prob[k]
    return OrderedDict([
        (key,tokens_prob[key])
        for key in sorted(tokens_prob, key=kf, reverse=True)[:n]
    ])

# get_top_prob_token( get_next_token_prob(sentence) )

# %% [markdown]
# ----

# %%
# генерируем продолжения

for sentence in sample(text_,10):
    if len(sentence)<5: continue
    tokens_next = get_top_prob_token( get_next_token_prob(sentence[:-2]) )
        
    print( 
        ' '.join(sentence[:-2])+  '...' + str(list(tokens_next.keys())) + '\n'
    )
# Out:
# - согласен согласен я с вами совершенно согласен но это у нас рано рано -...['я', 'вы', 'да']
#
# - зато тебе выгодно как шпиону...['и']
#
# в этом интимном кружке толпившемся около нее конечно между молодежью позволялось и даже вошло в правило делать разные шалости - действительно иногда...['впрочем', 'тоже', 'рассмешу']
#
# - и в новый суд его не потащил-с -...['я', 'вы', 'да']
#
# казалось это был сильный брюнет сухощавый и смуглый глаза были большие непременно черные с сильным блеском и с желтым отливом как у цыган это и в...['этом', 'то', 'самом']
#
# да хоть бы с третьего а не со второго слова а...['не', 'вы', 'я']
#
# вы ко мне пристаете почти что...['я', 'вы', 'он']
#
# вам ничего не значит пожертвовать жизнью и своею...['рукой', 'истиной', 'дорогой']
#
# чрезмерная подписка манила на расходы хотели сделать что-то чудесное - вот почему...['же', 'я', 'мне']
