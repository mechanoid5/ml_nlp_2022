# %% [markdown]
# **Статистическая языковая модель**
#
# Евгений Борисов <esborisov@sevsu.ru>
#
# (оцениваем наиболее вероятное продолжение для слова)

# %%
import nltk
import gzip

# %%
# !ls ../data

# %%
file_name = '../data/dostoevsky-besy-p2.txt.gz'

with gzip.open(file_name,'rt') as f:  text = f.read()[105:]
print(text[:364].strip())
# Out:
# Теперь, когда уже все прошло, и я пишу хронику, мы уже знаем в чем дело; но тогда мы еще ничего не знали, и естественно, что нам представлялись странными разные вещи. По крайней мере мы со Степаном Трофимовичем в первое время заперлись и с испугом наблюдали издали. Я-то кой-куда еще выходил и по-прежнему приносил ему разные вести, без чего он и пробыть не мог.

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import re

text_ = [ 
    word_tokenize( 
        re.sub(r'[^а-яa-z-]', ' ', s.lower())
    )  
    for s in sent_tokenize(text) 
]
text_[:2]
# Out:
# [['теперь',
#   'когда',
#   'уже',
#   'все',
#   'прошло',
#   'и',
#   'я',
#   'пишу',
#   'хронику',
#   'мы',
#   'уже',
#   'знаем',
#   'в',
#   'чем',
#   'дело',
#   'но',
#   'тогда',
#   'мы',
#   'еще',
#   'ничего',
#   'не',
#   'знали',
#   'и',
#   'естественно',
#   'что',
#   'нам',
#   'представлялись',
#   'странными',
#   'разные',
#   'вещи'],
#  ['по',
#   'крайней',
#   'мере',
#   'мы',
#   'со',
#   'степаном',
#   'трофимовичем',
#   'в',
#   'первое',
#   'время',
#   'заперлись',
#   'и',
#   'с',
#   'испугом',
#   'наблюдали',
#   'издали']]

# %%
from nltk.util import ngrams

text_ngrams = [ ngram for s in text_ for ngram in ngrams(s,2) ]

# %%
from collections import Counter

text_ngrams_cnt = dict( Counter(text_ngrams) )
text_ngrams_cnt
# Out:
# {('теперь', 'когда'): 5,
#  ('когда', 'уже'): 6,
#  ('уже', 'все'): 3,
#  ('все', 'прошло'): 1,
#  ('прошло', 'и'): 2,
#  ('и', 'я'): 34,
#  ('я', 'пишу'): 2,
#  ('пишу', 'хронику'): 1,
#  ('хронику', 'мы'): 1,
#  ('мы', 'уже'): 1,
#  ('уже', 'знаем'): 1,
#  ('знаем', 'в'): 1,
#  ('в', 'чем'): 18,
#  ('чем', 'дело'): 4,
#  ('дело', 'но'): 2,
#  ('но', 'тогда'): 1,
#  ('тогда', 'мы'): 1,
#  ('мы', 'еще'): 4,
#  ('еще', 'ничего'): 3,
#  ('ничего', 'не'): 56,
#  ('не', 'знали'): 5,
#  ('знали', 'и'): 1,
#  ('и', 'естественно'): 1,
#  ('естественно', 'что'): 1,
#  ('что', 'нам'): 1,
#  ('нам', 'представлялись'): 1,
#  ('представлялись', 'странными'): 1,
#  ('странными', 'разные'): 1,
#  ('разные', 'вещи'): 1,
#  ('по', 'крайней'): 35,
#  ('крайней', 'мере'): 34,
#  ('мере', 'мы'): 1,
#  ('мы', 'со'): 4,
#  ('со', 'степаном'): 5,
#  ('степаном', 'трофимовичем'): 7,
#  ('трофимовичем', 'в'): 1,
#  ('в', 'первое'): 1,
#  ('первое', 'время'): 1,
#  ('время', 'заперлись'): 1,
# ...

# %%
import itertools

text_cnt = dict( # оценка частоты использования слов
    Counter( itertools.chain(*text_)) 
) 

text_cnt
# Out:
# {'теперь': 180,
#  'когда': 126,
#  'уже': 183,
#  'все': 503,
#  'прошло': 3,
#  'и': 2983,
#  'я': 1267,
#  'пишу': 2,
#  'хронику': 2,
#  'мы': 131,
#  'знаем': 6,
#  'в': 1750,
#  'чем': 92,
#  'дело': 73,
#  'но': 666,
#  'тогда': 96,
#  'еще': 278,
#  'ничего': 130,
#  'не': 1777,
#  'знали': 14,
#  'естественно': 1,
#  'что': 1310,
#  'нам': 26,
#  'представлялись': 2,
#  'странными': 3,
#  'разные': 11,
#  'вещи': 10,
#  'по': 334,
#  'крайней': 36,
#  'мере': 41,
#  'со': 92,
#  'степаном': 7,
#  'трофимовичем': 7,
#  'первое': 2,
#  'время': 72,
#  'заперлись': 2,
#  'с': 862,
#  'испугом': 5,
#  'наблюдали': 1,
#  'издали': 2,
#  'я-то': 6,
#  'кой-куда': 1,
#  'выходил': 3,
#  'по-прежнему': 10,
#  'приносил': 1,
#  'ему': 138,
#  'вести': 5,
#  'без': 105,
#  'чего': 62,
#  'он': 822,
#  'пробыть': 2,
#  'мог': 64,
#  'нечего': 12,
#  'говорить': 42,
#  'городу': 8,
#  'пошли': 7,
#  'самые': 12,
#  'разнообразные': 1,
#  'слухи': 5,
#  'то-есть': 63,
#  'насчет': 18,
# ...

# %%
text_ngrams_prob = { # оценка совместного использования слов биграммы
    ngram : text_ngrams_cnt[ngram] / text_cnt[ ngram[0] ] 
    for ngram in text_ngrams_cnt 
}

text_ngrams_prob
# Out:
# {('теперь', 'когда'): 0.027777777777777776,
#  ('когда', 'уже'): 0.047619047619047616,
#  ('уже', 'все'): 0.01639344262295082,
#  ('все', 'прошло'): 0.0019880715705765406,
#  ('прошло', 'и'): 0.6666666666666666,
#  ('и', 'я'): 0.011397921555481059,
#  ('я', 'пишу'): 0.0015785319652722968,
#  ('пишу', 'хронику'): 0.5,
#  ('хронику', 'мы'): 0.5,
#  ('мы', 'уже'): 0.007633587786259542,
#  ('уже', 'знаем'): 0.00546448087431694,
#  ('знаем', 'в'): 0.16666666666666666,
#  ('в', 'чем'): 0.010285714285714285,
#  ('чем', 'дело'): 0.043478260869565216,
#  ('дело', 'но'): 0.0273972602739726,
#  ('но', 'тогда'): 0.0015015015015015015,
#  ('тогда', 'мы'): 0.010416666666666666,
#  ('мы', 'еще'): 0.030534351145038167,
#  ('еще', 'ничего'): 0.01079136690647482,
#  ('ничего', 'не'): 0.4307692307692308,
#  ('не', 'знали'): 0.0028137310073157004,
#  ('знали', 'и'): 0.07142857142857142,
#  ('и', 'естественно'): 0.00033523298692591353,
#  ('естественно', 'что'): 1.0,
# ...

# %%
from pprint import pprint
from random import sample

pprint(
{  # для случайной выборки слов печататаем пары с оценкой вероятности
    w0:{ 
        ngram[1]:text_ngrams_prob[ngram] 
        for ngram in text_ngrams_prob 
        if ngram[0] == w0 
    }
    for w0 in sample(text_cnt.keys(),10)
}
)
# Out:
# {'вскипела': {'варвара': 0.5, 'и': 0.5},
#  'вызывал': {},
#  'выносил': {'неприятнейшие': 1.0},
#  'заслужили': {'коли': 1.0},
#  'испуге': {'а': 0.2, 'вырвал': 0.2, 'смешанном': 0.2},
#  'по-ученому': {},
#  'поступке': {'студента': 1.0},
#  'произошло': {'в': 0.14285714285714285,
#                'даже': 0.07142857142857142,
#                'движение': 0.07142857142857142,
#                'и': 0.07142857142857142,
#                'много': 0.07142857142857142,
#                'от': 0.07142857142857142,
#                'отвечал': 0.07142857142857142,
#                'сильное': 0.07142857142857142,
#                'тогда': 0.07142857142857142,
#                'у': 0.07142857142857142,
#                'это': 0.21428571428571427},
#  'просителя': {'с': 1.0},
#  'укоренять': {'в': 1.0}}

# %%
# cnt = Counter(text_ngrams)
# dict(cnt)

# %%
# подсчёт совместного использования слов zip, collections.count

# %%
# from collections import Counter

# %%
# import re
# from nltk.util import ngrams

# s = 'the rain in spain falls mainly in the plains'#.split()
# s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
# tokens = [token for token in s.split(" ") if token != ""]
# tokens

# output = list(ngrams(tokens, 2))
# output

# %%
# from collections import Counter
# from nltk.corpus import reuters

# counts = Counter(reuters.words())
# total_count = len(reuters.words())
 
# # The most common 20 words are ...
# print(counts.most_common(n=20))
# # [(u'.', 94687), (u',', 72360), (u'the', 58251), (u'of', 35979), (u'to', 34035), (u'in', 26478), (u'said', 25224), (u'and', 25043), (u'a', 23492), (u'mln', 18037), (u'vs', 14120), (u'-', 13705), (u'for', 12785), (u'dlrs', 11730), (u"'", 11272), (u'The', 10968), (u'000', 10277), (u'1', 9977), (u's', 9298), (u'pct', 9093)]
 
# # Compute the frequencies
# for word in counts:
#     counts[word] /= float(total_count)

# # The frequencies should add up to 1
# print(sum(counts.values()))  # 1.0
 
# import random
 
# # Generate 100 words of language
# text = []
 
# for _ in range(100):
#     r = random.random()
#     accumulator = .0
 
#     for word, freq in counts.iteritems():
#         accumulator += freq
 
#         if accumulator >= r:
#             text.append(word)
#             break

# print(' '.join(text))

# %%
# from nltk.tokenize import sent_tokenize

# sent_tokenize(text)

# sentence_detector = nltk.data.load('tokenizers/punkt/russian.pickle')
# sentence_detector.tokenize(text)

# %%
# .tokenize.punkt

# sentence_detector.tokenize(text)

# >>> sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
# >>> print('\n-----\n'.join(sent_detector.tokenize(text.strip())))

# %%
# from nltk.tokenize import WordPunctTokenizer
# print(WordPunctTokenizer().tokenize(text))

# %%
# help(nltk.tokenize.punkt) #.PunktWordTokenizer

# %%
# >>> sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
# >>> print('\n-----\n'.join(sent_detector.tokenize(text.strip())))


# nltk.data.load(file_name)

# %%
# nltk.PunktWordTokenizer().tokenize(text)

# nltk.PunktWordTokenizer().tokenize(text)

# %%
# from nltk.model import ngram # as NgramModel

# %%
# obs = 'the rain in spain falls mainly in the plains'.split()
# lm = nltk.model.NgramModel(2, obs, estimator=nltk.MLEProbDist)

# %%
# >>> obs = 'the rain in spain falls mainly in the plains'.split()
# >>> lm = nltk.NgramModel(2, obs, estimator=nltk.MLEProbDist)
# >>> lm.prob('rain', 'the') #wrong
# 0.0
# >>> lm.prob('rain', ['the']) #right
# 0.5
# >>> lm.prob('spain', 'rain in') #wrong
# 0.0
# >>> lm.prob('spain', ['rain in']) #wrong
# '''long exception'''
# >>> lm.prob('spain', ['rain', 'in']) #right
# 1.0

# %%
import re
from nltk.util import ngrams

s = 'the rain in spain falls mainly in the plains'#.split()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
tokens = [token for token in s.split(" ") if token != ""]
tokens

output = list(ngrams(tokens, 2))
output
# Out:
# [('the', 'rain'),
#  ('rain', 'in'),
#  ('in', 'spain'),
#  ('spain', 'falls'),
#  ('falls', 'mainly'),
#  ('mainly', 'in'),
#  ('in', 'the'),
#  ('the', 'plains')]
